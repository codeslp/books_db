# %% [markdown]
# # Creating tables in the db

# %%
import os
import re
from datetime import date
import ast

import numpy as np
from scipy import stats
import pandas as pd
from pandas.tseries.offsets import *
from sqlalchemy import create_engine, text
from dotenv import load_dotenv

# %% [markdown]
# Reading dfs from parquet files:

# %%
award_df = pd.read_parquet('/Users/bfaris96/Desktop/turing-proj/books_db/data/award_df.parquet')
char_df = pd.read_parquet('/Users/bfaris96/Desktop/turing-proj/books_db/data/char_df.parquet')
creator_df = pd.read_parquet('/Users/bfaris96/Desktop/turing-proj/books_db/data/creator_df.parquet')
edition_df = pd.read_parquet('/Users/bfaris96/Desktop/turing-proj/books_db/data/edition_df.parquet')
genre_df = pd.read_parquet('/Users/bfaris96/Desktop/turing-proj/books_db/data/genre_df.parquet')
setting_df = pd.read_parquet('/Users/bfaris96/Desktop/turing-proj/books_db/data/setting_df.parquet')
star_rating_df = pd.read_parquet('/Users/bfaris96/Desktop/turing-proj/books_db/data/star_rating_df.parquet')

# %%
load_dotenv()

DB_USER = os.getenv("DB_USER")
DB_PASSWORD = os.getenv("DB_PASSWORD")
DB_HOST = os.getenv("DB_HOST")
DB_NAME = os.getenv("DB_NAME")

# %load_ext sql
# %sql postgresql://postgres:password@localhost/books
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ## Creating tables

# %% [markdown]
# Creating edition table with dtypes

# %%
for col in setting_df.columns:
    print(f'{col}: {setting_df[col].astype(str).apply(len).max()}, dtype: {setting_df[col].dtype}')
# Out:
# edition_id: 5, dtype: int64
# setting: 87, dtype: object

# %%
longest = edition_df['series_num'].astype(str).apply(len).max()
longest
# Out:
# 4

# %%
# %%sql
#
# DROP TABLE IF EXISTS edition CASCADE;
# CREATE TABLE edition (
#     edition_id serial PRIMARY KEY,
#     title varchar(300),
#     isbn varchar(13),
#     rating real,
#     num_ratings bigint,
#     liked_percent real,
#     bbe_score bigint,
#     bbe_votes bigint,
#     format varchar(64),
#     edition varchar(400),
#     series varchar(120),
#     series_num varchar(8),
#     publish_date date,
#     first_publish_date date,
#     language varchar(64),
#     pages smallint,
#     publisher varchar(250),
#     cover_url varchar(250),
#     price real,
#     is_duplicate_isbn boolean,
#     description varchar(29000)
# );
# Out:
#  * postgresql://postgres:***@localhost/books
# Done.
# Done.
# []

# %% [markdown]
# Creating genre table with dtypes

# %%
# %%sql
#
# DROP TABLE IF EXISTS genre;
# CREATE TABLE genre (
#     edition_id bigint NOT NULL,
#     FOREIGN KEY (edition_id) REFERENCES edition(edition_id),
#     genre varchar(40),
#     PRIMARY KEY (edition_id, genre)
# );
# Out:
#  * postgresql://postgres:***@localhost/books
# Done.
# Done.
# []

# %%
for col in char_df.columns:
    print(f'{col}: {char_df[col].astype(str).apply(len).max()}, dtype: {char_df[col].dtype}')
# Out:
# edition_id: 5, dtype: int64
# char_name: 128, dtype: object

# %% [markdown]
# Creating character table & datatypes

# %%
# %%sql
#
# DROP TABLE IF EXISTS character;
# CREATE TABLE character (
#     edition_id bigint NOT NULL,
#     FOREIGN KEY (edition_id) REFERENCES edition (edition_id),
#     char_name varchar(255),
#     PRIMARY KEY (edition_id, char_name)
#     );
# Out:
#  * postgresql://postgres:***@localhost/books
# Done.
# Done.
# []

# %% [markdown]
# Creating setting table:

# %%
# %%sql
#
# DROP TABLE IF EXISTS setting;
# CREATE table setting (
#     edition_id bigint NOT NULL,
#     FOREIGN KEY (edition_id) REFERENCES edition(edition_id),
#     setting varchar(100),
#     PRIMARY KEY (edition_id, setting)
# );
# Out:
#  * postgresql://postgres:***@localhost/books
# Done.
# Done.
# []

# %% [markdown]
# Creating star_rating table:

# %%
# %%sql
#
# DROP TABLE IF EXISTS star_rating;
# CREATE TABLE star_rating (
#     edition_id bigint NOT NULL,
#     FOREIGN KEY (edition_id) REFERENCES edition(edition_id),
#     five_star bigint,
#     four_star bigint,
#     three_star bigint,
#     two_star bigint,
#     one_star bigint,
#     PRIMARY KEY (edition_id, five_star, four_star, three_star, two_star, one_star)
#     );
# Out:
#  * postgresql://postgres:***@localhost/books
# Done.
# Done.
# []

# %% [markdown]
# Creating award table:

# %%
# %%sql
#
# DROP TABLE IF EXISTS award;
# CREATE TABLE award (
#     edition_id bigint NOT NULL,
#     FOREIGN KEY (edition_id) REFERENCES edition(edition_id),
#     award varchar(400),
#     award_year smallint,
#     PRIMARY KEY (edition_id, award)
# );
# Out:
#  * postgresql://postgres:***@localhost/books
# Done.
# Done.
# []

# %% [markdown]
# Creating creator table:

# %%
# %%sql
#
# DROP TABLE IF EXISTS creator;
# CREATE TABLE creator (
#     edition_id bigint NOT NULL,
#     FOREIGN KEY (edition_id) REFERENCES edition (edition_id),
#     creator_name varchar(128),
#     role varchar(64),
#     PRIMARY KEY (edition_id, creator_name, role)
# );
# Out:
#  * postgresql://postgres:***@localhost/books
# Done.
# Done.
# []

# %% [markdown]
# Loading data from dfs into tables:

# %%
# Create sqlalchemy engine
engine = create_engine(f"postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}/{DB_NAME}")

# %%
edition_df.to_sql('edition', engine, if_exists='append', index=False)
# Out:
# 428

# %%
# %%sql
#
# SELECT * from edition limit 5;
# Out:
#  * postgresql://postgres:***@localhost/books
# 5 rows affected.
# [(0, 'The Hunger Games', '9780439023481', 4.33, 6376780, 96.0, 2993816, 30516, 'Hardcover', 'First Edition', 'The Hunger Games', '1', datetime.date(2008, 9, 14), None, 'English', 374, 'Scholastic Press', 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1586722975l/2767052.jpg', 5.09, False, "WINNING MEANS FAME AND FORTUNE.LOSING MEANS CERTAIN DEATH.THE HUNGER GAMES HAVE BEGUN. . . .In the ruins of a place once known as North America lies  ... (543 characters truncated) ... to, she becomes a contender. But if she is to win, she will have to start making choices that weight survival against humanity and life against love."),
#  (1, 'Harry Potter and the Order of the Phoenix', '9780439358071', 4.5, 2507623, 98.0, 2632233, 26923, 'Paperback', 'US Edition', 'Harry Potter', '5', datetime.date(2004, 9, 28), datetime.date(2003, 6, 21), 'English', 870, 'Scholastic Inc.', 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1546910265l/2.jpg', 7.38, False, 'There is a door at the end of a silent corridor. And it’s haunting Harry Pottter’s dreams. Why else would he be waking in the middle of the night, sc ... (507 characters truncated) ...  depth and strength of his friends, the importance of boundless loyalty, and the shocking price of unbearable sacrifice.His fate depends on them all.'),
#  (2, 'To Kill a Mockingbird', None, 4.28, 4501075, 95.0, 2269402, 23328, 'Paperback', None, 'To Kill a Mockingbird', None, datetime.date(2006, 5, 23), datetime.date(1960, 7, 11), 'English', 324, 'Harper Perennial Modern Classics', 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1553383690l/2657.jpg', None, True, 'The unforgettable novel of a childhood in a sleepy Southern town and the crisis of conscience that rocked it, To Kill A Mockingbird became both an in ... (516 characters truncated) ... aims universal appeal. Harper Lee always considered her book to be a simple love story. Today it is regarded as a masterpiece of American literature.'),
#  (3, 'Pride and Prejudice', '9780679783268', 4.26, 2998241, 94.0, 1983116, 20452, 'Paperback', 'Modern Library Classics, USA / CAN', None, None, datetime.date(2000, 10, 10), datetime.date(1913, 1, 28), 'English', 279, 'Modern Library', 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1320399351l/1885.jpg', None, True, 'Alternate cover edition of ISBN 9780679783268Since its immediate success in 1813, Pride and Prejudice has remained one of the most popular novels in  ... (351 characters truncated) ... rkles as her characters dance a delicate quadrille of flirtation and intrigue, making this book the most superb comedy of manners of Regency England.'),
#  (4, 'Twilight', '9780316015844', 3.6, 4964519, 78.0, 1459448, 14874, 'Paperback', None, 'The Twilight Saga', '1', datetime.date(2006, 9, 6), datetime.date(2005, 10, 5), 'English', 501, 'Little, Brown and Company', 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1361039443l/41865.jpg', 2.1, False, "About three things I was absolutely positive.\r \r First, Edward was a vampire.\r \r Second, there was a part of him—and I didn't know how dominant t ... (59 characters truncated) ... d, I was unconditionally and irrevocably in love with him.\r \r Deeply seductive and extraordinarily suspenseful, Twilight is a love story with bite.")]

# %%
edition_df.head()
# Out:
#                                        title           isbn  rating  \
# 0                           The Hunger Games  9780439023481    4.33
# 1  Harry Potter and the Order of the Phoenix  9780439358071    4.50
# 2                      To Kill a Mockingbird           None    4.28
# 3                        Pride and Prejudice  9780679783268    4.26
# 4                                   Twilight  9780316015844    3.60
#
#    num_ratings  liked_percent  bbe_score  bbe_votes     format  \
# 0      6376780           96.0    2993816      30516  Hardcover
# 1      2507623           98.0    2632233      26923  Paperback
# 2      4501075           95.0    2269402      23328  Paperback
# 3      2998241           94.0    1983116      20452  Paperback
# 4      4964519           78.0    1459448      14874  Paperback
#
#                               edition                 series  ...  \
# 0                       First Edition       The Hunger Games  ...
# 1                          US Edition           Harry Potter  ...
# 2                                None  To Kill a Mockingbird  ...
# 3  Modern Library Classics, USA / CAN                   None  ...
# 4                                None      The Twilight Saga  ...
#
#   publish_date first_publish_date  \
# 0   2008-09-14                NaT
# 1   2004-09-28         2003-06-21
# 2   2006-05-23         1960-07-11
# 3   2000-10-10         1913-01-28
# 4   2006-09-06         2005-10-05
#
#                                          description language pages  \
# 0  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  English   374
# 1  There is a door at the end of a silent corrido...  English   870
# 2  The unforgettable novel of a childhood in a sl...  English   324
# 3  Alternate cover edition of ISBN 9780679783268S...  English   279
# 4  About three things I was absolutely positive.\...  English   501
#
#                           publisher  \
# 0                  Scholastic Press
# 1                   Scholastic Inc.
# 2  Harper Perennial Modern Classics
# 3                    Modern Library
# 4         Little, Brown and Company
#
#                                            cover_url price edition_id  \
# 0  https://i.gr-assets.com/images/S/compressed.ph...  5.09          0
# 1  https://i.gr-assets.com/images/S/compressed.ph...  7.38          1
# 2  https://i.gr-assets.com/images/S/compressed.ph...  None          2
# 3  https://i.gr-assets.com/images/S/compressed.ph...  None          3
# 4  https://i.gr-assets.com/images/S/compressed.ph...   2.1          4
#
#    is_duplicate_isbn
# 0              False
# 1              False
# 2               True
# 3               True
# 4              False
#
# [5 rows x 21 columns]

# %%
genre_df.to_sql('genre', engine, if_exists='append', index=False)
# Out:
# 373

# %%
# %%sql
#
# SELECT * from genre limit 25;
# Out:
#  * postgresql://postgres:***@localhost/books
# 25 rows affected.
# [(0, 'Young Adult'),
#  (0, 'Fiction'),
#  (0, 'Dystopia'),
#  (0, 'Fantasy'),
#  (0, 'Science Fiction'),
#  (0, 'Romance'),
#  (0, 'Adventure'),
#  (0, 'Teen'),
#  (0, 'Post Apocalyptic'),
#  (0, 'Action'),
#  (1, 'Fantasy'),
#  (1, 'Young Adult'),
#  (1, 'Fiction'),
#  (1, 'Magic'),
#  (1, 'Childrens'),
#  (1, 'Adventure'),
#  (1, 'Audiobook'),
#  (1, 'Middle Grade'),
#  (1, 'Classics'),
#  (1, 'Science Fiction Fantasy'),
#  (2, 'Classics'),
#  (2, 'Fiction'),
#  (2, 'Historical Fiction'),
#  (2, 'School'),
#  (2, 'Literature')]

# %%
char_df.to_sql('character', engine, if_exists='append', index=False)
# Out:
# 160

# %%
# %%sql
#
# SELECT * from character limit 25;
# Out:
#  * postgresql://postgres:***@localhost/books
# 25 rows affected.
# [(0, 'Katniss Everdeen'),
#  (0, 'Peeta Mellark'),
#  (0, 'Cato (Hunger Games)'),
#  (0, 'Primrose Everdeen'),
#  (0, 'Gale Hawthorne'),
#  (0, 'Effie Trinket'),
#  (0, 'Haymitch Abernathy'),
#  (0, 'Cinna'),
#  (0, 'President Coriolanus Snow'),
#  (0, 'Rue'),
#  (0, 'Flavius'),
#  (0, 'Lavinia (Hunger Games)'),
#  (0, 'Marvel'),
#  (0, 'Glimmer'),
#  (0, 'Clove'),
#  (0, 'Foxface'),
#  (0, 'Thresh'),
#  (0, 'Greasy Sae'),
#  (0, 'Madge Undersee'),
#  (0, 'Caesar Flickerman'),
#  (0, 'Claudius Templesmith'),
#  (0, 'Octavia (Hunger Games)'),
#  (0, 'Portia (hunger Games)'),
#  (1, 'Sirius Black'),
#  (1, 'Draco Malfoy')]

# %%
setting_df.to_sql('setting', engine, if_exists='append', index=False)
# Out:
# 280

# %%
# %%sql
#
# SELECT * FROM setting limit 25;
# Out:
#  * postgresql://postgres:***@localhost/books
# 25 rows affected.
# [(0, 'District 12, Panem'),
#  (0, 'Capitol, Panem'),
#  (0, 'Panem (United States)'),
#  (1, 'Hogwarts School of Witchcraft and Wizardry (United Kingdom)'),
#  (1, 'London, England'),
#  (2, 'Maycomb, Alabama (United States)'),
#  (3, 'United Kingdom'),
#  (3, 'Derbyshire, England (United Kingdom)'),
#  (3, 'England'),
#  (3, 'Hertfordshire, England (United Kingdom)'),
#  (4, 'Forks, Washington (United States)'),
#  (4, 'Phoenix, Arizona (United States)'),
#  (4, 'Washington (state) (United States)'),
#  (5, 'Molching (Germany)'),
#  (5, 'Germany'),
#  (6, 'England'),
#  (6, 'United Kingdom'),
#  (7, 'London, England'),
#  (8, 'Middle-earth'),
#  (9, 'Atlanta, Georgia (United States)'),
#  (10, 'Indianapolis, Indiana (United States)'),
#  (10, 'Amsterdam (Netherlands)'),
#  (13, 'Yorkshire Dales, England'),
#  (14, 'Paris (France)'),
#  (14, 'London, England')]

# %%
star_rating_df.to_sql('star_rating', engine, if_exists='append', index=False)
# Out:
# 6

# %%
# %%sql
#
# SELECT * FROM star_rating LIMIT 5;
# Out:
#  * postgresql://postgres:***@localhost/books
# 5 rows affected.
# [(0, 3444695, 1921313, 745221, 171994, 93557),
#  (1, 1593642, 637516, 222366, 39573, 14526),
#  (2, 2363896, 1333153, 573280, 149952, 80794),
#  (3, 1617567, 816659, 373311, 113934, 76770),
#  (4, 1751460, 1113682, 1008686, 542017, 548674)]

# %%
award_df.to_sql('award', engine, if_exists='append', index=False)
# Out:
# 527

# %%
# %%sql
#
# SELECT * FROM award LIMIT 25;
# Out:
#  * postgresql://postgres:***@localhost/books
# 25 rows affected.
# [(0, 'Locus Award Nominee for Best Young Adult Book', 2009),
#  (0, 'Georgia Peach Book Award', 2009),
#  (0, 'Buxtehuder Bulle', 2009),
#  (0, 'Golden Duck Award for Young Adult (Hal Clement Award)', 2009),
#  (0, "Grand Prix de l'Imaginaire Nominee for Roman jeunesse étranger", 2010),
#  (0, 'Books I Loved Best Yearly (BILBY) Awards for Older Readers', 2012),
#  (0, "West Australian Young Readers' Book Award (WAYRBA) for Older Readers", 2010),
#  (0, "Red House Children's Book Award for Older Readers & Overall", 2010),
#  (0, 'South Carolina Book Award for Junior and Young Adult Book', 2011),
#  (0, 'Charlotte Award', 2010),
#  (0, 'Colorado Blue Spruce Young Adult Book Award', 2010),
#  (0, 'Teen Buckeye Book Award', 2009),
#  (0, "Pennsylvania Young Readers' Choice Award for Young Adults", 2010),
#  (0, 'Rhode Island Teen Book Award', 2010),
#  (0, "Dorothy Canfield Fisher Children's Book Award", 2010),
#  (0, 'Evergreen Teen Book Award', 2011),
#  (0, 'Soaring Eagle Book Award', 2009),
#  (0, 'Milwaukee County Teen Book Award Nominee', 2010),
#  (0, 'Sakura Medal for Middle School Book', 2010),
#  (0, 'Michigan Library Association Thumbs Up! Award', 2009),
#  (0, 'Florida Teens Read', 2009),
#  (0, 'Deutscher Jugendliteraturpreis for Preis der Jugendjury', 2010),
#  (0, 'Iowa High School Book Award', 2011),
#  (0, 'New Mexico Land of Enchantment Award for Young Adult', 2011),
#  (0, 'Eliot Rosewater Indiana High School Book Award', 2010)]

# %%
creator_df.to_sql('creator', engine, if_exists='append', index=False)
# Out:
# 560

# %%
# %%sql
#
# SELECT * FROM creator LIMIT 5;
# Out:
#  * postgresql://postgres:***@localhost/books
# 5 rows affected.
# [(0, 'Suzanne Collins', 'missing'),
#  (1, 'J.K. Rowling', 'missing'),
#  (1, 'Mary GrandPré', 'Illustrator'),
#  (2, 'Harper Lee', 'missing'),
#  (3, 'Jane Austen', 'missing')]

# %%
# %%sql
# SELECT title, first_publish_date, COUNT(*)
# from edition
# GROUP BY title, first_publish_date
# having COUNT(*) > 1;
# Out:
#  * postgresql://postgres:***@localhost/books
# 570 rows affected.
# [('Blood Bound', None, 2),
#  ('Stinger', None, 2),
#  ('Asunder', None, 2),
#  ('Haven', None, 4),
#  ('Pride', None, 2),
#  ('The Prize', None, 2),
#  ('Inferno', None, 5),
#  ('Remember Me', None, 3),
#  ('Rapture', None, 2),
#  ('Limits of Destiny', None, 4),
#  ('Undertow', None, 2),
#  ('Return to Paradise', None, 2),
#  ('Secret Histories', None, 2),
#  ('Breathe', None, 2),
#  ('The Restorer', None, 2),
#  ('Silence', None, 4),
#  ('Faith', None, 2),
#  ('Running Wild', None, 2),
#  ('Beautiful Chaos', None, 2),
#  ('Pie in the Sky', None, 2),
#  ('Forget Me Not', None, 2),
#  ('Everything Changes', None, 2),
#  ("Time's Edge", None, 2),
#  ('The Raven', None, 2),
#  ('Rush', None, 2),
#  ('Ash', None, 2),
#  ('Retribution', None, 4),
#  ('The Keeper', None, 2),
#  ('The Missing', None, 2),
#  ('The Black Sheep', None, 2),
#  ('Afterlife', None, 3),
#  ('Missing', None, 2),
#  ('Deliver Us from Evil', None, 2),
#  ('Little Girl Gone', None, 2),
#  ('Wonderland', None, 2),
#  ('Just Breathe', None, 3),
#  ('Hero', None, 5),
#  ('Crazy', None, 2),
#  ('Best Friends', None, 2),
#  ('Secret', None, 3),
#  ('The Protector', None, 2),
#  ('House Rules', None, 2),
#  ('Monsters', None, 3),
#  ('Fury', None, 2),
#  ('The Lie', None, 2),
#  ('Unleashed', None, 2),
#  ('Intertwined', None, 2),
#  ('Phantom', None, 2),
#  ('Angelic', None, 2),
#  ('Falling Under', None, 2),
#  ('The Truth', None, 2),
#  ('Secrets', None, 4),
#  ('Genesis', None, 2),
#  ('Prince of Wolves', None, 2),
#  ('Vanished', None, 4),
#  ('Edgedancer', datetime.date(2016, 11, 22), 2),
#  ('The Quest', None, 2),
#  ('Stay', None, 3),
#  ('Serena', None, 2),
#  ('Dark Angel', None, 2),
#  ('Fragments', None, 2),
#  ('Cyclops', None, 2),
#  ('Insight', None, 3),
#  ('The Forgotten Ones', None, 2),
#  ('Annabel', None, 2),
#  ('The Capture', None, 2),
#  ('True Colors', None, 2),
#  ('The Rescue', None, 2),
#  ('Trapped', None, 2),
#  ('Never Never', None, 2),
#  ('Conviction', None, 3),
#  ('In the Dark', None, 3),
#  ('The Bet', None, 2),
#  ('Entice', None, 2),
#  ('Beauty', None, 3),
#  ('Emissary', None, 2),
#  ('Arena', None, 2),
#  ('Crush', None, 3),
#  ('Blaze', None, 2),
#  ('Unraveling', None, 2),
#  ('Darkest Night', None, 2),
#  ('Everlasting', None, 3),
#  ('Norwegian Wood', datetime.date(1987, 9, 4), 2),
#  ('The Talisman', None, 2),
#  ('Hunted', None, 6),
#  ('The Shadows', None, 4),
#  ('Hexed', None, 2),
#  ('Legion', None, 2),
#  ('Blackout', None, 6),
#  ('Breathless', None, 3),
#  ('Entangled', None, 3),
#  ('The Crown', None, 2),
#  ('The Queen', None, 3),
#  ('Close to Home', None, 2),
#  ('Mute: Poems That Saved My Life!: Poems by Vidya Gargote During Her Journey Battling with Depression', None, 2),
#  ('Perfect', None, 6),
#  ('Forever', None, 4),
#  ('The Day Before', None, 2),
#  ('Fire with Fire', None, 2),
#  ('Rebirth', None, 3),
#  ('Hidden', None, 2),
#  ('The Selection', None, 2),
#  ('Sáu Người Đi Khắp Thế Gian', None, 2),
#  ('The Deep', None, 3),
#  ('The Major Works', None, 3),
#  ('So Much More', None, 2),
#  ('Shift', None, 5),
#  ('Tease', None, 2),
#  ('Word of Honor', None, 2),
#  ('Find Me', None, 3),
#  ('Fall of Night', None, 2),
#  ('Shadow', None, 4),
#  ('The Outcast', None, 3),
#  ('Ruin', None, 3),
#  ('The Lost', None, 2),
#  ('Crossroads', None, 2),
#  ('By Any Other Name', datetime.date(2012, 10, 29), 2),
#  ('Untamed', None, 6),
#  ('Trailer Trash', None, 2),
#  ('Treasure', None, 2),
#  ('Nightfall', None, 2),
#  ('The End', None, 2),
#  ('Remains', None, 2),
#  ('Never Have I Ever', None, 2),
#  ('Snuff', None, 2),
#  ('Hostage', None, 2),
#  ('The Prey', None, 2),
#  ('Horizon', None, 2),
#  ('Eternity', None, 2),
#  ('Spencer', None, 2),
#  ('Coraline', datetime.date(2002, 1, 24), 2),
#  ('Blood for Blood', None, 2),
#  ('Valiant', None, 2),
#  ('Black', None, 2),
#  ('Blind Love', None, 2),
#  ('White', None, 2),
#  ('Sanctum', None, 2),
#  ('Endgame', None, 2),
#  ('Frantic', None, 2),
#  ('Vincent', None, 2),
#  ('The Devil Inside', None, 2),
#  ('Mine', None, 2),
#  ('Beautiful Creatures', None, 2),
#  ('The Witch Hunter', None, 2),
#  ('Fledgling', None, 2),
#  ('Destroy Me', None, 3),
#  ('The Darkest Hour', None, 3),
#  ('Nightlife', None, 2),
#  ('Huntress', None, 2),
#  ('Wayfarer', None, 2),
#  ('Trust', None, 2),
#  ('Deception', None, 3),
#  ('Mariposa capoeirista', None, 3),
#  ('Resonance', None, 2),
#  ('The Rising', None, 2),
#  ('Revelations', None, 2),
#  ('In Too Deep', None, 4),
#  ('Fearless', None, 3),
#  ('True', None, 3),
#  ('Bloodlust', None, 3),
#  ('No Mercy', None, 2),
#  ('First', None, 2),
#  ('Resurrection', None, 2),
#  ('Sea Change', None, 2),
#  ('What She Left Behind', None, 2),
#  ('Firelight', None, 3),
#  ('Destined', None, 2),
#  ('Aftermath', None, 3),
#  ('Dreamer', None, 2),
#  ('The Calling', None, 2),
#  ('Shattered', None, 5),
#  ('Inherit the Stars', None, 2),
#  ('Carpe Diem', None, 2),
#  ('Three Wishes', None, 3),
#  ('Taken', None, 4),
#  ('The Warrior', None, 2),
#  ('Silver', None, 4),
#  ('Going Home', None, 2),
#  ('The Insider', None, 2),
#  ('Black Ice', None, 3),
#  ('Magnolia', None, 2),
#  ('Nine Lives', None, 2),
#  ('Falling In', None, 2),
#  ('After the End', None, 2),
#  ('Harbinger', None, 2),
#  ('Cursed', None, 4),
#  ('The Dragonet Prophecy', None, 2),
#  ('Soulless', None, 2),
#  ('The Heartbreakers', None, 2),
#  ('Alice', None, 2),
#  ('Wild', None, 2),
#  ('Broken', None, 10),
#  ('Endangered', None, 2),
#  ('Guardian', None, 3),
#  ('Undone', None, 2),
#  ('The Drop', None, 2),
#  ('Les Miserables', None, 2),
#  ('Relentless', None, 2),
#  ('Wings', None, 2),
#  ('Wake', None, 2),
#  ('Haunted', None, 4),
#  ('Tremble', None, 2),
#  ('Flame', None, 2),
#  ('Darkling', None, 2),
#  ('The Way of Kings', None, 2),
#  ('Contagion', None, 2),
#  ("Don't You Forget About Me", None, 2),
#  ('Songbird', None, 2),
#  ('Smolder', None, 2),
#  ('Out of Control', None, 2),
#  ('Return', None, 2),
#  ('Thin Air', None, 2),
#  ('Widzę cię', datetime.date(2013, 11, 6), 2),
#  ('Lucas', None, 2),
#  ('Personal Demons', None, 2),
#  ('Mirage', None, 5),
#  ('Deceptions', None, 2),
#  ('Beast', None, 2),
#  ('Origins', None, 4),
#  ('Stormy Weather', None, 2),
#  ('The Choice', None, 3),
#  ('The Keepsake', None, 2),
#  ('Bad Things', None, 3),
#  ('Playing With Fire', None, 2),
#  ('Dark Matter', None, 2),
#  ('Ruined', None, 4),
#  ('The Lost Heir', None, 2),
#  ('Oblivion', None, 3),
#  ('Jet', None, 2),
#  ('Dust', None, 2),
#  ('Time of the Dragons', None, 2),
#  ('Branded', None, 2),
#  ('Black Dawn', None, 2),
#  ('Exile', None, 2),
#  ('Dead Souls', None, 2),
#  ('The Proposal', None, 2),
#  ('Little Women', datetime.date(1968, 9, 30), 2),
#  ('Invincible', None, 2),
#  ('The King', None, 2),
#  ('A Time to Dance', None, 2),
#  ('Night School', None, 2),
#  ('Burned', None, 3),
#  ('Endless Magic', None, 2),
#  ('New Moon', None, 2),
#  ('Escape', None, 2),
#  ('Ghost in the Machine', None, 2),
#  ('Unravel Me', None, 2),
#  ('Unbroken', None, 2),
#  ('Legend', None, 2),
#  ('First Contact', None, 2),
#  ('Lost and Found', None, 2),
#  ('Home for the Holidays', None, 2),
#  ('Marked', None, 3),
#  ('The Summoning', None, 2),
#  ("Don't Breathe a Word", None, 2),
#  ('Obsession', None, 3),
#  ('Panic', None, 2),
#  ('Fractured', None, 4),
#  ('From a Distance', None, 2),
#  ('Pleasure', None, 2),
#  ('Adam', None, 3),
#  ('The Legacy', None, 3),
#  ('Hunter', None, 2),
#  ('Going Under', None, 2),
#  ('Eye of the Storm', None, 3),
#  ('Save Me', None, 2),
#  ('Become', None, 2),
#  ('The Best Man', None, 2),
#  ('Breaking Point', None, 2),
#  ('Vampire Academy', None, 2),
#  ('Defy', None, 2),
#  ('One Small Thing', None, 2),
#  ('Dangerous', None, 2),
#  ('Silhouette', None, 2),
#  ('Beyond Reach', None, 2),
#  ('Blood Kiss', None, 2),
#  ('Coming Home', None, 4),
#  ('Control', None, 3),
#  ('Runaway', None, 2),
#  ('Dark Space', None, 2),
#  ('Tempted', None, 2),
#  ('Fairest', None, 2),
#  ('Gun Control', None, 2),
#  ('Darkness Unleashed', None, 2),
#  ('Still Life', None, 2),
#  ('الأعمال الشعرية الكاملة', None, 2),
#  ('Sacrifice', None, 3),
#  ('Restart', None, 2),
#  ('Shine', None, 2),
#  ('Unspoken', None, 2),
#  ('Wolfsangel', None, 2),
#  ('Simply Irresistible', None, 2),
#  ('Hush', None, 2),
#  ('See How They Run', None, 2),
#  ('Ashes, Ashes', None, 2),
#  ('Switch', None, 2),
#  ('The Confession', None, 2),
#  ('Bloodlines', None, 2),
#  ('By a Thread', None, 2),
#  ('The Reckoning', None, 3),
#  ('Anguish', None, 2),
#  ('A Rush of Wings', None, 2),
#  ('I Dare', None, 2),
#  ('Reflections', None, 2),
#  ('Red Queen', None, 2),
#  ('The Line', None, 2),
#  ('Slade', None, 2),
#  ('Raven', None, 4),
#  ("'Salem's Lot", datetime.date(1975, 10, 17), 2),
#  ('Charmed', None, 3),
#  ('Remember When', None, 2),
#  ('The Cure', None, 2),
#  ('Nemesis', None, 3),
#  ('Abandon', None, 2),
#  ('Awakened', None, 2),
#  ('Birthright', None, 3),
#  ('Fallen', None, 3),
#  ('Vengeful', None, 2),
#  ('The Stranger', None, 2),
#  ('Evermore', None, 2),
#  ('Black City', None, 2),
#  ('Wraith', None, 2),
#  ('Dead of Night', None, 2),
#  ('The Amulet of Samarkand', None, 2),
#  ('The Hunted', None, 3),
#  ('Awakening', None, 4),
#  ('The Search', None, 3),
#  ('Twisted', None, 8),
#  ('Silent Scream', None, 2),
#  ('The World We Live In A Poetry Book On Societal Issues', None, 2),
#  ('The Stolen Child', None, 3),
#  ('Black Heart', None, 3),
#  ('Swarm', None, 2),
#  ('Desired', None, 2),
#  ('Always and Forever', None, 2),
#  ('Only Human', None, 2),
#  ('Exposure', None, 2),
#  ('Stolen', None, 4),
#  ('Flawless', None, 2),
#  ("Don't Let Go", None, 2),
#  ('Wicked', None, 2),
#  ('Against All Odds', None, 2),
#  ('The Gift', None, 2),
#  ('Dangerous Games', None, 2),
#  ('Crave', None, 2),
#  ('Ashes', None, 2),
#  ('Stranded', None, 2),
#  ('Cinderella', None, 2),
#  ('Driven', None, 2),
#  ('SIMPLY INFILTRATING THOUGHT "You Will Only Understand Self Ability Via A Self Push" "Holistic Combination Discovery"', None, 2),
#  ('Euphoria', None, 2),
#  ('Wolfsbane', None, 3),
#  ('Possession', None, 2),
#  ('The Watcher', None, 2),
#  ('The Final Storm', None, 2),
#  ('Conjured', None, 2),
#  ('Betrothed', None, 2),
#  ('The Elementals', None, 2),
#  ('Over My Dead Body', None, 2),
#  ('Finders Keepers', None, 3),
#  ('What Happened to Suzy', None, 2),
#  ('Out of the Picture and Into the Picture', None, 2),
#  ('The Book of Spells', None, 2),
#  ('The Darkest Kiss', None, 2),
#  ('Dead City', None, 2),
#  ('Unbreakable', None, 2),
#  ('Legacy', None, 8),
#  ('Deadly Secrets', None, 2),
#  ('Ice Station', datetime.date(1998, 8, 1), 2),
#  ('Protect and Defend', None, 2),
#  ('The Raven King', None, 2),
#  ('Burn', None, 8),
#  ('Scoundrels', None, 2),
#  ('Zero at the Bone', None, 2),
#  ('Dark Magic', None, 2),
#  ('Savior', None, 2),
#  ('His', None, 2),
#  ('The Power', None, 2),
#  ('Bloodline', None, 2),
#  ('Hourglass', None, 2),
#  ('Takedown', None, 2),
#  ('Vicious', None, 3),
#  ('Eternal', None, 2),
#  ('Betrayal', None, 4),
#  ('Revelation', None, 4),
#  ('Shattered Sky', None, 2),
#  ('Undetected', None, 2),
#  ('The Association', None, 2),
#  ('The Mahabharata', None, 2),
#  ('The Forsaken', None, 3),
#  ('Collide', None, 2),
#  ('Selected Poems', None, 2),
#  ('Twilight', None, 2),
#  ('Clean', None, 2),
#  ("A Sister's Promise", None, 2),
#  ('Chosen', None, 5),
#  ('Dead Heat', None, 2),
#  ('Wicked Game', None, 3),
#  ('Thief', None, 2),
#  ('Second Chances', None, 3),
#  ('Freefall', None, 5),
#  ("Vampire's Kiss", None, 2),
#  ('Wrecking Ball', None, 2),
#  ('Impossible', None, 2),
#  ('Once Burned', None, 2),
#  ('Dream Chaser', None, 2),
#  ('Blood Will Tell', None, 2),
#  ('The Chosen', None, 4),
#  ('Rise', None, 2),
#  ('Cupcake', None, 2),
#  ('Toxic', None, 2),
#  ('The Firm', datetime.date(1991, 2, 28), 2),
#  ('Take Me', None, 3),
#  ('Inheritance', None, 2),
#  ('Prince of Dreams', None, 2),
#  ('Redemption', None, 6),
#  ('Come Away with Me', None, 2),
#  ('Entwined', None, 3),
#  ('Cupping Therapy Encyclopedia: New Edition', None, 2),
#  ('Infamous', None, 3),
#  ('Torn', None, 3),
#  ('Beneath the Surface', None, 2),
#  ('Mirror Image', None, 2),
#  ('Crossing the Line', None, 3),
#  ('The Reapers', None, 2),
#  ('Haunted Moon', None, 2),
#  ('Bliss', None, 2),
#  ('The Change', None, 2),
#  ('Poison', None, 2),
#  ('Forbidden', None, 6),
#  ('Sweet Revenge', None, 2),
#  ('More Than Anything', None, 2),
#  ('Lost & Found', None, 2),
#  ('Breakthrough', None, 2),
#  ('Consumed', None, 2),
#  ('Pulse', None, 2),
#  ('Suspicion', None, 2),
#  ('Waterfall', None, 2),
#  ('Cole', None, 2),
#  ('Plague', None, 2),
#  ('Captivate', None, 2),
#  ('The Secret', None, 2),
#  ('Skin Deep', None, 4),
#  ('Collision Course', None, 2),
#  ('Awaken', None, 2),
#  ('Castle Grey - A Katt and Mouse Mystery', None, 2),
#  ('Rapture (A Been So Long Prequel)', None, 2),
#  ('Pandora', None, 2),
#  ('The Tithe Debate', None, 2),
#  ('How To Win Football Bets Easily, Every Time: Top Secrets, Tips And Best Strategies For Winning Big', None, 2),
#  ('Immortal', None, 2),
#  ('Assassin', None, 2),
#  ('The Forgetting', None, 2),
#  ('She Died', None, 2),
#  ('Monster', None, 2),
#  ('Revenge', None, 3),
#  ('Destiny', None, 3),
#  ('Weapon', None, 2),
#  ('The Gathering Storm', None, 3),
#  ('Wayward Son', None, 2),
#  ('Double Trouble', None, 2),
#  ('Reckless', None, 6),
#  ('Wildfire', None, 2),
#  ('The Return', None, 2),
#  ('Thicker Than Water', None, 4),
#  ('Wolf Hall', datetime.date(2009, 4, 30), 2),
#  ('Free Fall', None, 2),
#  ('The Female Factory', None, 2),
#  ('The Story of Us', None, 2),
#  ('Trouble', None, 2),
#  ('Neverland', None, 2),
#  ('Nightshade', None, 2),
#  ('The Awakening', None, 2),
#  ('Changeling', None, 3),
#  ('Kiss of Fire', None, 2),
#  ('Spellbound', None, 2),
#  ('Seeker', None, 2),
#  ('Damned', None, 2),
#  ('Conspiracy', None, 3),
#  ('The Becoming', None, 2),
#  ('Life in Motion: An Unlikely Ballerina', None, 2),
#  ('Glimmer', None, 2),
#  ('Origin', None, 3),
#  ('The Planet Pirates', datetime.date(1993, 11, 6), 2),
#  ('The Other Woman', None, 2),
#  ('Smoke', None, 2),
#  ('The Friend Zone', None, 2),
#  ('Stronghold', None, 2),
#  ('Rage', None, 2),
#  ('Fever', None, 2),
#  ('The Long Way Home', None, 2),
#  ('The Last Word', None, 2),
#  ('Alpha', None, 2),
#  ('Against the Wall', None, 2),
#  ('The List', None, 2),
#  ('The Rising Tide', None, 2),
#  ('Sinner', None, 2),
#  ('The Hunt', None, 3),
#  ('Echo', None, 3),
#  ('Elemental', None, 3),
#  ('Untitled', None, 4),
#  ('Heartless', None, 5),
#  ('The Rook', None, 2),
#  ('Impulse', None, 2),
#  ('Angel', None, 3),
#  ('Poderosa', datetime.date(2006, 11, 6), 2),
#  ('Fate', None, 2),
#  ('Omega', None, 2),
#  ('Voyager', datetime.date(1993, 12, 1), 2),
#  ('The Fold', None, 2),
#  ('The Hollow', None, 2),
#  ('Claimed', None, 2),
#  ('Diamond Dogs', datetime.date(2000, 9, 1), 2),
#  ('Flight', None, 2),
#  ('Sanctuary', None, 2),
#  ('The Nameless Encounter', None, 2),
#  ('Shiver', None, 3),
#  ('The Haunted', None, 2),
#  ('Between the Lines', None, 2),
#  ('Wanted', None, 2),
#  ('Storm', None, 3),
#  ('Blood Hunt', None, 2),
#  ('Homecoming', None, 2),
#  ('Making the Cut', None, 2),
#  ('Becoming', None, 2),
#  ('In the End', None, 2),
#  ('Extreme Measures', None, 2),
#  ('Pure', None, 2),
#  ('Avenger', None, 2),
#  ('Envy', None, 2),
#  ('The Key', None, 2),
#  ('Beautiful Redemption', None, 2),
#  ('Home', None, 4),
#  ('Fated', None, 4),
#  ("The Dark God's Bride", None, 2),
#  ('The Turning', None, 3),
#  ('Masquerade', None, 2),
#  ('Nevermore', None, 6),
#  ('Break Me', None, 3),
#  ('Scarlet', None, 2),
#  ('The Other Side of Darkness', None, 2),
#  ('Rogue', None, 3),
#  ('A Trick of the Light', None, 2),
#  ('The Prince', None, 3),
#  ('Dark Fire', None, 2),
#  ('Gone', None, 2),
#  ('Soulmates', None, 2),
#  ('The Chase', None, 2),
#  ('Miss Match', None, 2),
#  ('Bang', None, 2),
#  ('Reckoning', None, 5),
#  ('Uninvited', None, 2),
#  ('Ignite', None, 3),
#  ('Crank', None, 2),
#  ('Forsaken', None, 4),
#  ('Last Days', None, 2),
#  ('All Through the Night', None, 3),
#  ('Wrath', None, 4),
#  ("I'll Be Seeing You", None, 2),
#  ('The Cursed', None, 2),
#  ('Warped', None, 2),
#  ('Missing You', None, 2),
#  ('The Hunter', None, 2),
#  ('Temptation', None, 3),
#  ('Just One Night', None, 2),
#  ('Wide Awake', None, 2),
#  ('Sweet Possession', None, 2),
#  ('Shadow Magic', None, 2),
#  ('Ecology', None, 2),
#  ('Within These Walls', None, 2)]

# %% [markdown]
# Creating a read only DB user (I realize this is commented out code, but I left it in to prove that I know how to do this):

# %%
"""
# %%sql

CREATE USER book_reader WITH PASSWORD 'read_only';
GRANT CONNECT ON DATABASE books TO book_reader;
GRANT USAGE ON SCHEMA public TO book_reader;
GRANT SELECT ON ALL TABLES IN SCHEMA public TO book_reader;
ALTER DEFAULT PRIVILEGES IN SCHEMA public GRANT SELECT ON TABLES TO book_reader;
SELECT * FROM pg_roles;
"""
# Out:
# "\n%%sql\n\nCREATE USER book_reader WITH PASSWORD 'read_only';\nGRANT CONNECT ON DATABASE books TO book_reader;\nGRANT USAGE ON SCHEMA public TO book_reader;\nGRANT SELECT ON ALL TABLES IN SCHEMA public TO book_reader;\nALTER DEFAULT PRIVILEGES IN SCHEMA public GRANT SELECT ON TABLES TO book_reader;\nSELECT * FROM pg_roles;\n"
